# %% [markdown]
# # FinChart-R1 — Phase 1: Baseline & Robust Evaluation
#
# This notebook is a Colab-friendly entry point for the reusable Phase 1 code. Phase 1 evaluates a frozen Qwen3-VL baseline; it does not train SFT or GRPO models.

# %%
# In Colab, clone this repository first, then install dependencies.
# !git clone <YOUR_REPOSITORY_URL>
# %cd FinChart-R1
# !pip install -r requirements.txt
import sys
from pathlib import Path
ROOT = Path.cwd()
sys.path.insert(0, str(ROOT / 'src'))

# %%
# Run baseline once. Existing result files are reused by default.
# !python scripts/run_baseline.py --config configs/phase1.yaml

# %%
# Set JUDGE_API_KEY, JUDGE_BASE_URL, and JUDGE_MODEL in the Colab environment,
# then judge only deterministic mismatches.
# !python scripts/run_judge.py --config configs/phase1.yaml
# !python scripts/analyze_results.py --config configs/phase1.yaml
